# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sklearn.linear_model

# %%
# Load data
df = pd.read_csv("datasets/oecd_bli_2015.csv", thousands=',')

# %%
# View first n rows (default 5)
df.head()
# Out:
#   LOCATION         Country INDICATOR                           Indicator  \
# 0      AUS       Australia   HO_BASE  Dwellings without basic facilities
# 1      AUT         Austria   HO_BASE  Dwellings without basic facilities
# 2      BEL         Belgium   HO_BASE  Dwellings without basic facilities
# 3      CAN          Canada   HO_BASE  Dwellings without basic facilities
# 4      CZE  Czech Republic   HO_BASE  Dwellings without basic facilities
#
#   MEASURE Measure INEQUALITY Inequality Unit Code        Unit  PowerCode Code  \
# 0       L   Value        TOT      Total        PC  Percentage               0
# 1       L   Value        TOT      Total        PC  Percentage               0
# 2       L   Value        TOT      Total        PC  Percentage               0
# 3       L   Value        TOT      Total        PC  Percentage               0
# 4       L   Value        TOT      Total        PC  Percentage               0
#
#   PowerCode  Reference Period Code  Reference Period  Value Flag Codes  \
# 0     units                    NaN               NaN    1.1          E
# 1     units                    NaN               NaN    1.0        NaN
# 2     units                    NaN               NaN    2.0        NaN
# 3     units                    NaN               NaN    0.2        NaN
# 4     units                    NaN               NaN    0.9        NaN
#
#              Flags
# 0  Estimated value
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %%
# Vuew last n rows:
df.tail(6)
# Out:
#      LOCATION       Country INDICATOR  \
# 3286      CHL         Chile   WL_TNOW
# 3287      EST       Estonia   WL_TNOW
# 3288      ISR        Israel   WL_TNOW
# 3289      RUS        Russia   WL_TNOW
# 3290      SVN      Slovenia   WL_TNOW
# 3291     OECD  OECD - Total   WL_TNOW
#
#                                       Indicator MEASURE Measure INEQUALITY  \
# 3286  Time devoted to leisure and personal care       L   Value        WMN
# 3287  Time devoted to leisure and personal care       L   Value        WMN
# 3288  Time devoted to leisure and personal care       L   Value        WMN
# 3289  Time devoted to leisure and personal care       L   Value        WMN
# 3290  Time devoted to leisure and personal care       L   Value        WMN
# 3291  Time devoted to leisure and personal care       L   Value        WMN
#
#      Inequality Unit Code   Unit  PowerCode Code PowerCode  \
# 3286      Women      HOUR  Hours               0     units
# 3287      Women      HOUR  Hours               0     units
# 3288      Women      HOUR  Hours               0     units
# 3289      Women      HOUR  Hours               0     units
# 3290      Women      HOUR  Hours               0     units
# 3291      Women      HOUR  Hours               0     units
#
#       Reference Period Code  Reference Period  Value Flag Codes  \
# 3286                    NaN               NaN  14.16          E
# 3287                    NaN               NaN  14.43        NaN
# 3288                    NaN               NaN  14.24          E
# 3289                    NaN               NaN  14.75          E
# 3290                    NaN               NaN  14.12        NaN
# 3291                    NaN               NaN  14.74        NaN
#
#                 Flags
# 3286  Estimated value
# 3287              NaN
# 3288  Estimated value
# 3289  Estimated value
# 3290              NaN
# 3291              NaN

# %%
# Basic info about the data frame:
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3292 entries, 0 to 3291
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   LOCATION               3292 non-null   object
#  1   Country                3292 non-null   object
#  2   INDICATOR              3292 non-null   object
#  3   Indicator              3292 non-null   object
#  4   MEASURE                3292 non-null   object
#  5   Measure                3292 non-null   object
#  6   INEQUALITY             3292 non-null   object
#  7   Inequality             3292 non-null   object
#  8   Unit Code              3292 non-null   object
#  9   Unit                   3292 non-null   object
#  10  PowerCode Code         3292 non-null   int64
#  11  PowerCode              3292 non-null   object
#  12  Reference Period Code  0 non-null      float64
#  13  Reference Period       0 non-null      float64
#  14  Value                  3292 non-null   float64
#  15  Flag Codes             1120 non-null   object
#  16  Flags                  1120 non-null   object
# dtypes: float64(3), int64(1), object(13)
# memory usage: 437.3+ KB

# %%
# Statistics summary of numeric columns
df.describe()
# Out:
#        PowerCode Code  Reference Period Code  Reference Period          Value
# count          3292.0                    0.0               0.0    3292.000000
# mean              0.0                    NaN               NaN    4774.392587
# std               0.0                    NaN               NaN   13941.537833
# min               0.0                    NaN               NaN       0.000000
# 25%               0.0                    NaN               NaN       6.600000
# 50%               0.0                    NaN               NaN      49.000000
# 75%               0.0                    NaN               NaN      90.000000
# max               0.0                    NaN               NaN  145769.000000

# %%
# Shape of the dataframe
df.shape
# Out:
# (3292, 17)

# %%
## COLUMN OPERATIONS

# %%
# 1. List all columns:
df.columns
# Out:
# Index(['LOCATION', 'Country', 'INDICATOR', 'Indicator', 'MEASURE', 'Measure',
#        'INEQUALITY', 'Inequality', 'Unit Code', 'Unit', 'PowerCode Code',
#        'PowerCode', 'Reference Period Code', 'Reference Period', 'Value',
#        'Flag Codes', 'Flags'],
#       dtype='object')

# %%
# 2. Select specific columns
basic_info = df[['Country', 'Indicator', 'Value']]
print(basic_info.head())
# Out:
#           Country                           Indicator  Value
# 0       Australia  Dwellings without basic facilities    1.1
# 1         Austria  Dwellings without basic facilities    1.0
# 2         Belgium  Dwellings without basic facilities    2.0
# 3          Canada  Dwellings without basic facilities    0.2
# 4  Czech Republic  Dwellings without basic facilities    0.9

# %%
# 3. Rename columns
df.rename(columns={'Country':'Nchi'})
# Out:
#      LOCATION            Nchi INDICATOR  \
# 0         AUS       Australia   HO_BASE
# 1         AUT         Austria   HO_BASE
# 2         BEL         Belgium   HO_BASE
# 3         CAN          Canada   HO_BASE
# 4         CZE  Czech Republic   HO_BASE
# ...       ...             ...       ...
# 3287      EST         Estonia   WL_TNOW
# 3288      ISR          Israel   WL_TNOW
# 3289      RUS          Russia   WL_TNOW
# 3290      SVN        Slovenia   WL_TNOW
# 3291     OECD    OECD - Total   WL_TNOW
#
#                                       Indicator MEASURE Measure INEQUALITY  \
# 0            Dwellings without basic facilities       L   Value        TOT
# 1            Dwellings without basic facilities       L   Value        TOT
# 2            Dwellings without basic facilities       L   Value        TOT
# 3            Dwellings without basic facilities       L   Value        TOT
# 4            Dwellings without basic facilities       L   Value        TOT
# ...                                         ...     ...     ...        ...
# 3287  Time devoted to leisure and personal care       L   Value        WMN
# 3288  Time devoted to leisure and personal care       L   Value        WMN
# 3289  Time devoted to leisure and personal care       L   Value        WMN
# 3290  Time devoted to leisure and personal care       L   Value        WMN
# 3291  Time devoted to leisure and personal care       L   Value        WMN
#
#      Inequality Unit Code        Unit  PowerCode Code PowerCode  \
# 0         Total        PC  Percentage               0     units
# 1         Total        PC  Percentage               0     units
# 2         Total        PC  Percentage               0     units
# 3         Total        PC  Percentage               0     units
# 4         Total        PC  Percentage               0     units
# ...         ...       ...         ...             ...       ...
# 3287      Women      HOUR       Hours               0     units
# 3288      Women      HOUR       Hours               0     units
# 3289      Women      HOUR       Hours               0     units
# 3290      Women      HOUR       Hours               0     units
# 3291      Women      HOUR       Hours               0     units
#
#       Reference Period Code  Reference Period  Value Flag Codes  \
# 0                       NaN               NaN   1.10          E
# 1                       NaN               NaN   1.00        NaN
# 2                       NaN               NaN   2.00        NaN
# 3                       NaN               NaN   0.20        NaN
# 4                       NaN               NaN   0.90        NaN
# ...                     ...               ...    ...        ...
# 3287                    NaN               NaN  14.43        NaN
# 3288                    NaN               NaN  14.24          E
# 3289                    NaN               NaN  14.75          E
# 3290                    NaN               NaN  14.12        NaN
# 3291                    NaN               NaN  14.74        NaN
#
#                 Flags
# 0     Estimated value
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 3287              NaN
# 3288  Estimated value
# 3289  Estimated value
# 3290              NaN
# 3291              NaN
#
# [3292 rows x 17 columns]

# %%
## DATA SELECTION & FILTERING

# 1. Select by position:
df.iloc[0] # First row
df.iloc[0:5] # First 5 rows
df.iloc[0:5, 0:2] # First 5 rows, first 2 columns
# Out:
#   LOCATION         Country
# 0      AUS       Australia
# 1      AUT         Austria
# 2      BEL         Belgium
# 3      CAN          Canada
# 4      CZE  Czech Republic

# %%
# 2. Select by label:
df.loc[:, 'LOCATION'] # Column
# Out:
# 0        AUS
# 1        AUT
# 2        BEL
# 3        CAN
# 4        CZE
#         ...
# 3287     EST
# 3288     ISR
# 3289     RUS
# 3290     SVN
# 3291    OECD
# Name: LOCATION, Length: 3292, dtype: object

# %%
#3. Filter data:
df[df['Value'] > 1]
# Out:
#      LOCATION       Country INDICATOR  \
# 0         AUS     Australia   HO_BASE
# 2         BEL       Belgium   HO_BASE
# 10        HUN       Hungary   HO_BASE
# 13        ITA         Italy   HO_BASE
# 14        JPN         Japan   HO_BASE
# ...       ...           ...       ...
# 3287      EST       Estonia   WL_TNOW
# 3288      ISR        Israel   WL_TNOW
# 3289      RUS        Russia   WL_TNOW
# 3290      SVN      Slovenia   WL_TNOW
# 3291     OECD  OECD - Total   WL_TNOW
#
#                                       Indicator MEASURE Measure INEQUALITY  \
# 0            Dwellings without basic facilities       L   Value        TOT
# 2            Dwellings without basic facilities       L   Value        TOT
# 10           Dwellings without basic facilities       L   Value        TOT
# 13           Dwellings without basic facilities       L   Value        TOT
# 14           Dwellings without basic facilities       L   Value        TOT
# ...                                         ...     ...     ...        ...
# 3287  Time devoted to leisure and personal care       L   Value        WMN
# 3288  Time devoted to leisure and personal care       L   Value        WMN
# 3289  Time devoted to leisure and personal care       L   Value        WMN
# 3290  Time devoted to leisure and personal care       L   Value        WMN
# 3291  Time devoted to leisure and personal care       L   Value        WMN
#
#      Inequality Unit Code        Unit  PowerCode Code PowerCode  \
# 0         Total        PC  Percentage               0     units
# 2         Total        PC  Percentage               0     units
# 10        Total        PC  Percentage               0     units
# 13        Total        PC  Percentage               0     units
# 14        Total        PC  Percentage               0     units
# ...         ...       ...         ...             ...       ...
# 3287      Women      HOUR       Hours               0     units
# 3288      Women      HOUR       Hours               0     units
# 3289      Women      HOUR       Hours               0     units
# 3290      Women      HOUR       Hours               0     units
# 3291      Women      HOUR       Hours               0     units
#
#       Reference Period Code  Reference Period  Value Flag Codes  \
# 0                       NaN               NaN   1.10          E
# 2                       NaN               NaN   2.00        NaN
# 10                      NaN               NaN   4.80        NaN
# 13                      NaN               NaN   1.10        NaN
# 14                      NaN               NaN   6.40        NaN
# ...                     ...               ...    ...        ...
# 3287                    NaN               NaN  14.43        NaN
# 3288                    NaN               NaN  14.24          E
# 3289                    NaN               NaN  14.75          E
# 3290                    NaN               NaN  14.12        NaN
# 3291                    NaN               NaN  14.74        NaN
#
#                 Flags
# 0     Estimated value
# 2                 NaN
# 10                NaN
# 13                NaN
# 14                NaN
# ...               ...
# 3287              NaN
# 3288  Estimated value
# 3289  Estimated value
# 3290              NaN
# 3291              NaN
#
# [3113 rows x 17 columns]

# %%
df[df['Country'].isin(['Japan', 'Israel'])]
# Out:
#      LOCATION Country INDICATOR                                  Indicator  \
# 14        JPN   Japan   HO_BASE         Dwellings without basic facilities
# 33        ISR  Israel   HO_BASE         Dwellings without basic facilities
# 51        JPN   Japan   HO_BASE         Dwellings without basic facilities
# 70        ISR  Israel   HO_BASE         Dwellings without basic facilities
# 87        JPN   Japan   HO_BASE         Dwellings without basic facilities
# ...       ...     ...       ...                                        ...
# 3214      ISR  Israel   WL_TNOW  Time devoted to leisure and personal care
# 3232      JPN   Japan   WL_TNOW  Time devoted to leisure and personal care
# 3251      ISR  Israel   WL_TNOW  Time devoted to leisure and personal care
# 3269      JPN   Japan   WL_TNOW  Time devoted to leisure and personal care
# 3288      ISR  Israel   WL_TNOW  Time devoted to leisure and personal care
#
#      MEASURE Measure INEQUALITY Inequality Unit Code        Unit  \
# 14         L   Value        TOT      Total        PC  Percentage
# 33         L   Value        TOT      Total        PC  Percentage
# 51         L   Value         MN        Men        PC  Percentage
# 70         L   Value         MN        Men        PC  Percentage
# 87         L   Value        WMN      Women        PC  Percentage
# ...      ...     ...        ...        ...       ...         ...
# 3214       L   Value        TOT      Total      HOUR       Hours
# 3232       L   Value         MN        Men      HOUR       Hours
# 3251       L   Value         MN        Men      HOUR       Hours
# 3269       L   Value        WMN      Women      HOUR       Hours
# 3288       L   Value        WMN      Women      HOUR       Hours
#
#       PowerCode Code PowerCode  Reference Period Code  Reference Period  \
# 14                 0     units                    NaN               NaN
# 33                 0     units                    NaN               NaN
# 51                 0     units                    NaN               NaN
# 70                 0     units                    NaN               NaN
# 87                 0     units                    NaN               NaN
# ...              ...       ...                    ...               ...
# 3214               0     units                    NaN               NaN
# 3232               0     units                    NaN               NaN
# 3251               0     units                    NaN               NaN
# 3269               0     units                    NaN               NaN
# 3288               0     units                    NaN               NaN
#
#       Value Flag Codes            Flags
# 14     6.40        NaN              NaN
# 33     3.70          E  Estimated value
# 51     6.40          E  Estimated value
# 70     3.70          E  Estimated value
# 87     6.40          E  Estimated value
# ...     ...        ...              ...
# 3214  14.48          E  Estimated value
# 3232  14.98        NaN              NaN
# 3251  14.65          E  Estimated value
# 3269  14.88        NaN              NaN
# 3288  14.24          E  Estimated value
#
# [178 rows x 17 columns]

# %%
## STATISTICS & AGGREGATION

# 1. Basic Statistics
df['Value'].mean()
df['Value'].median()
df['Value'].mode()
df['Value'].min()
df['Value'].max()
df['Value'].std()
# Out:
# 13941.5378326681

# %%
# 2. Group by operations
df.groupby('Country')['Value'].mean()
# Out:
# Country
# Australia           6267.896073
# Austria             6019.059822
# Belgium             7257.838220
# Brazil              1994.952908
# Canada              6708.151509
# Chile               2755.229627
# Czech Republic      2786.791761
# Denmark             5735.051600
# Estonia             2222.269720
# Finland             4493.590157
# France              5618.577255
# Germany             6012.104128
# Greece              3022.010949
# Hungary             2503.221751
# Iceland             5785.920712
# Ireland             5166.357437
# Israel              4783.771546
# Italy               5242.214604
# Japan               6382.745840
# Korea               4113.501405
# Luxembourg          7464.177342
# Mexico              2047.348742
# Netherlands         6964.230548
# New Zealand         4281.938270
# Norway              4947.473186
# OECD - Total        4451.821302
# Poland              2677.680974
# Portugal            3581.125497
# Russia              2467.332744
# Slovak Republic     2419.655631
# Slovenia            3558.214961
# Spain               4167.375201
# Sweden              5947.034454
# Switzerland         8558.713982
# Turkey              1859.787289
# United Kingdom      5985.486437
# United States      10622.746153
# Name: Value, dtype: float64

# %%
# 3. Check for missing values
df.isnull().sum()
# Out:
# LOCATION                    0
# Country                     0
# INDICATOR                   0
# Indicator                   0
# MEASURE                     0
# Measure                     0
# INEQUALITY                  0
# Inequality                  0
# Unit Code                   0
# Unit                        0
# PowerCode Code              0
# PowerCode                   0
# Reference Period Code    3292
# Reference Period         3292
# Value                       0
# Flag Codes               2172
# Flags                    2172
# dtype: int64

# %%
# 4. Handle Missing values
#df.dropna() # Drop rows with any missing values
df.fillna(0) # Fill missing values with 0
# Out:
#      LOCATION         Country INDICATOR  \
# 0         AUS       Australia   HO_BASE
# 1         AUT         Austria   HO_BASE
# 2         BEL         Belgium   HO_BASE
# 3         CAN          Canada   HO_BASE
# 4         CZE  Czech Republic   HO_BASE
# ...       ...             ...       ...
# 3287      EST         Estonia   WL_TNOW
# 3288      ISR          Israel   WL_TNOW
# 3289      RUS          Russia   WL_TNOW
# 3290      SVN        Slovenia   WL_TNOW
# 3291     OECD    OECD - Total   WL_TNOW
#
#                                       Indicator MEASURE Measure INEQUALITY  \
# 0            Dwellings without basic facilities       L   Value        TOT
# 1            Dwellings without basic facilities       L   Value        TOT
# 2            Dwellings without basic facilities       L   Value        TOT
# 3            Dwellings without basic facilities       L   Value        TOT
# 4            Dwellings without basic facilities       L   Value        TOT
# ...                                         ...     ...     ...        ...
# 3287  Time devoted to leisure and personal care       L   Value        WMN
# 3288  Time devoted to leisure and personal care       L   Value        WMN
# 3289  Time devoted to leisure and personal care       L   Value        WMN
# 3290  Time devoted to leisure and personal care       L   Value        WMN
# 3291  Time devoted to leisure and personal care       L   Value        WMN
#
#      Inequality Unit Code        Unit  PowerCode Code PowerCode  \
# 0         Total        PC  Percentage               0     units
# 1         Total        PC  Percentage               0     units
# 2         Total        PC  Percentage               0     units
# 3         Total        PC  Percentage               0     units
# 4         Total        PC  Percentage               0     units
# ...         ...       ...         ...             ...       ...
# 3287      Women      HOUR       Hours               0     units
# 3288      Women      HOUR       Hours               0     units
# 3289      Women      HOUR       Hours               0     units
# 3290      Women      HOUR       Hours               0     units
# 3291      Women      HOUR       Hours               0     units
#
#       Reference Period Code  Reference Period  Value Flag Codes  \
# 0                       0.0               0.0   1.10          E
# 1                       0.0               0.0   1.00          0
# 2                       0.0               0.0   2.00          0
# 3                       0.0               0.0   0.20          0
# 4                       0.0               0.0   0.90          0
# ...                     ...               ...    ...        ...
# 3287                    0.0               0.0  14.43          0
# 3288                    0.0               0.0  14.24          E
# 3289                    0.0               0.0  14.75          E
# 3290                    0.0               0.0  14.12          0
# 3291                    0.0               0.0  14.74          0
#
#                 Flags
# 0     Estimated value
# 1                   0
# 2                   0
# 3                   0
# 4                   0
# ...               ...
# 3287                0
# 3288  Estimated value
# 3289  Estimated value
# 3290                0
# 3291                0
#
# [3292 rows x 17 columns]

# %%
## DATA TRANSFORMATION
# 1. Sort values
df.sort_values('Country', ascending=True)
# Out:
#      LOCATION        Country INDICATOR                           Indicator  \
# 0         AUS      Australia   HO_BASE  Dwellings without basic facilities
# 619       AUS      Australia   JE_EMPL                     Employment rate
# 182       AUS      Australia   HO_HISH                 Housing expenditure
# 1932      AUS      Australia   EQ_AIRP                       Air pollution
# 1896      AUS      Australia   EQ_AIRP                       Air pollution
# ...       ...            ...       ...                                 ...
# 2809      USA  United States   SW_LIFS                   Life satisfaction
# 1961      USA  United States   EQ_AIRP                       Air pollution
# 211       USA  United States   HO_HISH                 Housing expenditure
# 2108      USA  United States  CG_TRASG         Consultation on rule-making
# 944       USA  United States   JE_LTUR         Long-term unemployment rate
#
#      MEASURE Measure INEQUALITY Inequality Unit Code  \
# 0          L   Value        TOT      Total        PC
# 619        L   Value        TOT      Total        PC
# 182        L   Value        WMN      Women        PC
# 1932       L   Value        WMN      Women  MICRO_M3
# 1896       L   Value         MN        Men  MICRO_M3
# ...      ...     ...        ...        ...       ...
# 2809       L   Value        HGH       High   AVSCORE
# 1961       L   Value        WMN      Women  MICRO_M3
# 211        L   Value        WMN      Women        PC
# 2108       L   Value        TOT      Total   AVSCORE
# 944        L   Value        TOT      Total        PC
#
#                             Unit  PowerCode Code PowerCode  \
# 0                     Percentage               0     units
# 619                   Percentage               0     units
# 182                   Percentage               0     units
# 1932  Micrograms per cubic metre               0     units
# 1896  Micrograms per cubic metre               0     units
# ...                          ...             ...       ...
# 2809               Average score               0     units
# 1961  Micrograms per cubic metre               0     units
# 211                   Percentage               0     units
# 2108               Average score               0     units
# 944                   Percentage               0     units
#
#       Reference Period Code  Reference Period  Value Flag Codes  \
# 0                       NaN               NaN   1.10          E
# 619                     NaN               NaN  72.00        NaN
# 182                     NaN               NaN  20.00          E
# 1932                    NaN               NaN  13.00          E
# 1896                    NaN               NaN  13.00          E
# ...                     ...               ...    ...        ...
# 2809                    NaN               NaN   7.50        NaN
# 1961                    NaN               NaN  18.00          E
# 211                     NaN               NaN  18.00          E
# 2108                    NaN               NaN   8.30        NaN
# 944                     NaN               NaN   1.91        NaN
#
#                 Flags
# 0     Estimated value
# 619               NaN
# 182   Estimated value
# 1932  Estimated value
# 1896  Estimated value
# ...               ...
# 2809              NaN
# 1961  Estimated value
# 211   Estimated value
# 2108              NaN
# 944               NaN
#
# [3292 rows x 17 columns]
